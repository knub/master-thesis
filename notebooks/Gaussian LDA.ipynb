# %%
# %matplotlib notebook

import itertools
from functools import partial
import numpy as np
import gensim, logging
import pandas as pnd
import scipy
from sklearn.cluster import *
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, RandomizedPCA
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
def plot_normal(mean, cov):
    points = np.random.multivariate_normal(mean, cov, 2500)
    plt.figure()
    plt.scatter(points[:,0], points[:,1])
    plt.xlim([-10, 10])
    plt.ylim([-10, 10])
    
    
mean = np.array([0.0, 0.0])
cov = np.array([[1.00, 0.9],
                [0.1, 1.0]])
plot_normal(mean, cov)
# Out:
# <img src="data:image/png;base64,...">

# %%
np.cov(points.transpose())
# Out:
# array([[ 0.68882758,  0.67164745],
#        [ 0.67164745,  2.08441741]])

# %%
normal_sample = np.random.normal(size=10000)
inverse_sample = 1.0 / normal_sample
inverse_sample = inverse_sample[inverse_sample > -5]
inverse_sample = inverse_sample[inverse_sample < +5]
plt.figure()
foo = plt.hist(inverse_sample, bins=100)
# Out:
# <img src="data:image/png;base64,...">

# %%
scale_matrix = np.array([[10.0, 0.0],
                         [0.0, 1.0]])
cov = scipy.stats.invwishart.rvs(df=10, scale=scale_matrix, size=1)

plot_normal(mean, cov)
# Out:
# <img src="data:image/png;base64,...">
